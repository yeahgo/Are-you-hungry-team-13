# %% [markdown]
# ## A Restaurant Recommendation System based on Yelp Information ##

# %%
import re
from threading import Thread
import pandas as pd

# %% [markdown]
# **The following cell is the code for recommendation engine:**

# %%
def ask_for_name(df):
    
    nl = []
    while True:
        print('Please enter a restaurant name below, if you have no idea about it, just click return\n')
        name=input("Restaurant name: \n")
        
        if name == '':
            return df
        
        for item in df['restaurant_name'].tolist():
            if isinstance(item, str):
                if re.search(name.lower(), item.lower()):
                    nl.append(item)
        
        if len(nl) == 0:
            print('Please enter a valid name.\n')
            continue
        else:
            break
    return df.loc[df['restaurant_name'].isin(nl)]

def ask_for_category(df):
    
    cl = []
    while True:
        print('Please enter a restaurant category below, if you have no idea about it, just click return\n')
        cat = input("Restaurant category: \n")
        
        if cat == '':
            return df
        
        for item in df['Category'].tolist():
            if isinstance(item, str):
                if re.search(cat.lower(), item.lower()):
                    cl.append(item)
        
        if len(cl) == 0:
            print('Please enter a valid category.\n')
            continue
        else:
            break
    return df.loc[df['Category'].isin(cl)]

def ask_for_neighbor(df):
    
    nl = []
    while True:
        print('Please enter a restaurant neighborhood below, if you have no idea about it, just click return\n')
        neighbor = input("Restaurant neighborhood: \n")
        
        if neighbor == '':
            return df
        
        for item in df['restaurant_neighborhood'].tolist():
            if isinstance(item, str):
                if re.search(neighbor.lower(), item.lower()):
                    nl.append(item)
                
        if len(nl) == 0:
            print("Please enter a valid neighborhood. \n")
            continue
        else:
            break
    
    return df.loc[df['restaurant_neighborhood'].isin(nl)]

def ask_for_rating(df):
    
    
    while True:
        try:
            print("Please enter a range of your expected rating below, if you have no idea about it, just click return\n")
            lb = input("Please enter a lower bound of rating range you are looking for :\n")
            ub = input("Please enter an upper bound of rating range you are looking for :\n")
        
            if lb == '' and ub == '':
                return df
        
            if lb == '':
                lb = '0'
        
            if ub == '':
                ub = '5'
            
            if float(lb) > float(ub):
                print('Lower bound has to be smaller than the upper bound.\n')
                continue
        
            if float(lb) < 0 or float(ub) > 5:
                print('The range of rating has to be between 0 and 5.\n')
                continue
            
            return df.loc[(df['restaurant_rating'] >= float(lb)) & (df['restaurant_rating'] <= float(ub))]
        
        except:
        
            print('Please provide a valid input\n')
            continue

# Credit to ZiYuan Wang
def ask_for_party(df):
    
    while True:
        print("Good for groups / parties?\n")
        PARTY = input("Please enter Y/N\n")
        
        if PARTY == 'Y':
            A = 'Yes'
        
        elif PARTY =='N':
            A='No'
            
        else: 
            continue
        
        return df.loc[df['Good for Groups']==A]
    
def ask_for_price(df):
    
    pl = []
    while True:
        try:
            print("Please enter a range of your expected price below, if you have no idea about it, just click return\n")
            lb = input("Please enter a lower bound of price range you are looking for :\n")
            ub = input("Please enter an upper bound of price range you are looking for :\n")
            if lb == '' and ub == '':
                return df
        
            for item in df['price_range'].tolist():
                if isinstance(item, str):
                    if re.search('^\$\d+-\d+$', item):
                        i1 = int(item[1:item.find('-')])
                        i2 = int(item[item.find('-')+1:])
                    
                        if float(lb) <= i1 or float(ub) >= i2:
                            pl.append(item)
                    elif 'Under' in item:
                    
                        if int(item[item.find('$')+1:]) >= float(lb):
                            pl.append(item)
                        
                    elif 'Above' in item:
                    
                        if int(item[item.find('$')+1:]) <= float(ub):
                            pl.append(item)
                        
            if len(pl) == 0:
                print("Unfortunately, there are no restaurants falling into your desired price range. Please try some other price range\n")
                continue
            else:
                
                return df.loc[df['price_range'].isin(pl)]
    
        except:
        
            print('Please provide a valid input\n')
            continue

# %% [markdown]
# ** Below is three demos for how to use the recommendation engine:**

# %%
# demo 1
global_df = pd.read_csv('final_df.csv', encoding='latin1')
done = False

while done == False:
    
    global_df = ask_for_name(global_df)
    length = len(global_df['restaurant_name'].tolist())
    print(f"There are {length} restaurants filtered out so far\n")
    con = input('Do you want to keep searching? Enter 0 if you are done with searching. Otherwise, enter anything else.\n')
    if con == '0':
        break
    
    while True:
        global_df = ask_for_category(global_df)
        length = len(global_df['restaurant_name'].tolist())
        print(f"There are {length} restaurants filtered out so far\n")
        con = input('Do you want to keep filtering based on Category? Enter 0 if you are done with searching. Otherwise, enter anything else.\n')
        if con == '0':
            break
        
    length = len(global_df['restaurant_name'].tolist())
    print(f"There are {length} restaurants filtered out so far\n")
    con = input('Do you want to keep searching? Enter 0 if you are done with searching. Otherwise, enter anything else.\n')
    if con == '0':
        break
        
    while True:
        global_df = ask_for_neighbor(global_df)
        length = len(global_df['restaurant_name'].tolist())
        print(f"There are {length} restaurants filtered out so far\n")
        con = input('Do you want to keep filtering based on Neighborhood? Enter 0 if you are done with searching. Otherwise, enter anything else.\n')
        if con == '0':
            break
    
    length = len(global_df['restaurant_name'].tolist())
    print(f"There are {length} restaurants filtered out so far\n")
    con = input('Do you want to keep searching? Enter 0 if you are done with searching. Otherwise, enter anything else.\n')
    if con == '0':
        break
    
    global_df = ask_for_rating(global_df)
    length = len(global_df['restaurant_name'].tolist())
    print(f"There are {length} restaurants filtered out so far\n")
    con = input('Do you want to keep searching? Enter 0 if you are done with searching. Otherwise, enter anything else.\n')
    if con == '0':
        break
    
    global_df = ask_for_price(global_df)
    length = len(global_df['restaurant_name'].tolist())
    print(f"There are {length} restaurants filtered out so far\n")
    con = input('Do you want to keep searching? Enter 0 if you are done with searching. Otherwise, enter anything else.\n')
    if con == '0':
        break
        
    global_df = ask_for_party(global_df)
    length = len(global_df['restaurant_name'].tolist())
    print(f"There are {length} restaurants filtered out so far\n")
    con = input('Do you want to keep searching? Enter 0 if you are done with searching. Otherwise, enter anything else.\n')
    if con == '0':
        break
        
    done = True
    
a4 = global_df
global_df
# Out:
# Please enter a restaurant name below, if you have no idea about it, just click return
#
# Restaurant name:
# asd
# Please enter a valid name.
#
# Please enter a restaurant name below, if you have no idea about it, just click return
#
# Restaurant name:
# we
# There are 38 restaurants filtered out so far
#
# Do you want to keep searching? Enter 0 if you are done with searching. Otherwise, enter anything else.
# 0
#       Unnamed: 0 Accepts Bitcoin Accepts Credit Cards           Alcohol  \
# 102           49             NaN                  Yes          Full Bar
# 165          114             NaN                  Yes  Beer & Wine Only
# 477          958             NaN                  Yes                No
# 627           76              No                  Yes  Beer & Wine Only
# 672          121             NaN                   No                No
# 760          209             NaN                  Yes  Beer & Wine Only
# 764          213             NaN                  Yes  Beer & Wine Only
# 785           18             NaN                  Yes          Full Bar
# 868          120             NaN                  Yes          Full Bar
# 882          134              No                  Yes  Beer & Wine Only
# 1051         146             NaN                  Yes                No
# 1089          52             NaN                  Yes  Beer & Wine Only
# 1111         115             NaN                  Yes  Beer & Wine Only
# 1171          14             NaN                  Yes          Full Bar
# 1371         665             NaN                  Yes          Full Bar
# 1388         743             NaN                  Yes          Full Bar
# 1647         174              No                  Yes                No
# 1712         239             NaN                  Yes                No
# 1743         270             NaN                  Yes                No
# 1757         284             NaN                  Yes                No
# 1767         294             NaN                  Yes          Full Bar
# 1773         300             NaN                  Yes                No
# 1810         337             NaN                  Yes                No
# 1976          13             NaN                  Yes          Full Bar
# 1984          21              No                  Yes  Beer & Wine Only
# 1995          32             NaN                  Yes                No
# 2027          64             NaN                  Yes          Full Bar
# 2086          28             NaN                  Yes                No
# 2173          58              No                  Yes          Full Bar
# 2262          11             NaN                  Yes          Full Bar
# 2302          51              No                  Yes  Beer & Wine Only
# 2310          59             NaN                  Yes          Full Bar
# 2321          70             NaN                  Yes          Full Bar
# 2357         106             NaN                  Yes          Full Bar
# 2361         110              No                  Yes                No
# 2404         153              No                  Yes  Beer & Wine Only
# 2450         199              No                  Yes  Beer & Wine Only
# 2493          22             NaN                  Yes          Full Bar
#
#                               Ambience  Attire Bike Parking  \
# 102                                NaN  Casual          NaN
# 165                             Casual  Casual          Yes
# 477                                NaN  Casual           No
# 627                             Casual  Casual          Yes
# 672                                NaN     NaN          NaN
# 760                             Casual     NaN          Yes
# 764                                NaN     NaN          Yes
# 785                             Casual  Casual          Yes
# 868                             Classy  Casual           No
# 882                             Casual  Casual          Yes
# 1051                               NaN  Casual          Yes
# 1089                     Divey, Casual  Casual          Yes
# 1111                               NaN     NaN          NaN
# 1171  Casual, Trendy, Romantic, Classy  Casual           No
# 1371                            Casual  Casual           No
# 1388  Casual, Trendy, Romantic, Classy  Casual           No
# 1647                            Casual  Casual          Yes
# 1712                            Casual  Casual          Yes
# 1743                            Casual     NaN          Yes
# 1757                    Casual, Trendy  Casual           No
# 1767                            Casual  Casual          Yes
# 1773                            Casual  Casual          Yes
# 1810                    Casual, Trendy  Casual          Yes
# 1976                            Casual  Casual          Yes
# 1984                            Casual  Casual          Yes
# 1995                            Casual  Casual          Yes
# 2027                            Casual  Casual           No
# 2086                            Casual  Casual          Yes
# 2173                            Casual  Casual          Yes
# 2262                            Casual  Casual          Yes
# 2302                            Casual  Casual          Yes
# 2310  Casual, Trendy, Romantic, Classy  Casual           No
# 2321                            Casual  Casual           No
# 2357                            Casual  Casual          Yes
# 2361                               NaN     NaN           No
# 2404                    Casual, Trendy  Casual          Yes
# 2450                            Casual  Casual          Yes
# 2493  Casual, Trendy, Romantic, Classy  Casual           No
#
#                                                Category Caters Delivery  \
# 102                                  Chinese; Hot Pot;     NaN       No
# 165                       Hot Pot; Szechuan; Barbeque;      No      Yes
# 477                                           Chinese;     Yes      Yes
# 627                                             Ramen;      No      Yes
# 672                                       Food Stands;     NaN       No
# 760                Asian Fusion; Chinese; Gluten-Free;      No       No
# 764                Chinese; Gluten-Free; Asian Fusion;     Yes       No
# 785                 Breweries; American (Traditional);      No       No
# 868                                    American (New);     Yes       No
# 882        American (Traditional); Beer Bar; Bakeries;     Yes      Yes
# 1051                                 Caterers; Indian;     NaN      Yes
# 1089                     Coffee & Tea; Latin American;      No      Yes
# 1111                                       Tapas Bars;     NaN       No
# 1171               French; Cocktail Bars; Steakhouses;     Yes      Yes
# 1371                     Italian; Desserts; Wine Bars;     Yes      Yes
# 1388               French; Cocktail Bars; Steakhouses;     Yes      Yes
# 1647                      Food Trucks; Thai; Caterers;     NaN       No
# 1712                                Salad; Vegetarian;      No       No
# 1743                  Vegetarian; Sandwiches; Falafel;     Yes      Yes
# 1757                                Salad; Vegetarian;     NaN       No
# 1767                   Sushi Bars; Asian Fusion; Bars;     Yes      Yes
# 1773                                Salad; Vegetarian;      No       No
# 1810                                Salad; Vegetarian;      No       No
# 1976                            Cajun/Creole; Seafood;     Yes      Yes
# 1984                                            Ramen;      No      Yes
# 1995                                Salad; Vegetarian;      No       No
# 2027                     Italian; Desserts; Wine Bars;     Yes      Yes
# 2086                         Indian; Pakistani; Halal;     Yes      Yes
# 2173                     Beer Gardens; American (New);     Yes      Yes
# 2262                Breweries; American (Traditional);      No       No
# 2302  American (Traditional); Comfort Food; Vegetari...    Yes      Yes
# 2310               French; Cocktail Bars; Steakhouses;     Yes      Yes
# 2321                     American (Traditional); Bars;     Yes      Yes
# 2357  American (Traditional); Breakfast & Brunch; Ba...    Yes      Yes
# 2361                                            Delis;     Yes      Yes
# 2404  Juice Bars & Smoothies; American (Traditional)...     No       No
# 2450  Breakfast & Brunch; American (Traditional); Ve...    Yes      Yes
# 2493               French; Cocktail Bars; Steakhouses;     Yes      Yes
#
#               ...           Waiter Service Wheelchair Accessible Wi-Fi  \
# 102           ...                      NaN                   NaN  Free
# 165           ...                      NaN                   Yes  Free
# 477           ...                      NaN                   NaN    No
# 627           ...                      NaN                   NaN    No
# 672           ...                      NaN                   NaN   NaN
# 760           ...                      NaN                   NaN    No
# 764           ...                       No                   NaN    No
# 785           ...                      Yes                   NaN  Free
# 868           ...                      Yes                   Yes  Free
# 882           ...                      NaN                   Yes    No
# 1051          ...                      NaN                   NaN    No
# 1089          ...                      NaN                   NaN    No
# 1111          ...                      Yes                    No  Free
# 1171          ...                      Yes                   Yes  Free
# 1371          ...                      NaN                   NaN  Free
# 1388          ...                      Yes                   Yes  Free
# 1647          ...                      NaN                   NaN    No
# 1712          ...                      NaN                   NaN  Free
# 1743          ...                      NaN                   NaN  Free
# 1757          ...                       No                   NaN    No
# 1767          ...                      NaN                   NaN    No
# 1773          ...                       No                   NaN  Free
# 1810          ...                       No                   NaN    No
# 1976          ...                      Yes                   Yes    No
# 1984          ...                      NaN                   NaN    No
# 1995          ...                       No                   NaN  Free
# 2027          ...                      NaN                   NaN  Free
# 2086          ...                      Yes                   Yes  Free
# 2173          ...                      Yes                   Yes  Free
# 2262          ...                      Yes                   NaN  Free
# 2302          ...                      Yes                   Yes    No
# 2310          ...                      Yes                   Yes  Free
# 2321          ...                      NaN                   NaN    No
# 2357          ...                      Yes                   Yes  Free
# 2361          ...                       No                   Yes    No
# 2404          ...                       No                   Yes  Free
# 2450          ...                      NaN                   NaN  Free
# 2493          ...                      Yes                   Yes  Free
#
#      price_range                                   restaurant_name  \
# 102          NaN                                     Zhen Wei Fang
# 165       $11-30                   Hot Kitchen Skewer Hotpot & BBQ
# 477    Under $10                                          Shun Wei
# 627       $11-30                           Jin Ramen - West Harlem
# 672    Under $10                            Happy Well Being House
# 760    Under $10                                           Pei Wei
# 764       $11-30                                           Pei Wei
# 785       $11-30                                 Bricktown Brewery
# 868       $31-60                                       Bowery Road
# 882       $11-30                                  Westville - East
# 1051   Under $10                   Punjabi Dhaba Catering & Sweets
# 1089   Under $10                              Westside Coffee Shop
# 1111      $11-30                               Lamano West Village
# 1171      $31-60                            Boucherie West Village
# 1371      $11-30    Carmine?s Italian Restaurant - Upper West Side
# 1388      $31-60                            Boucherie West Village
# 1647   Under $10                                       Sweet Chili
# 1712      $11-30                                        sweetgreen
# 1743   Under $10                                 Taim West Village
# 1757      $11-30                                        sweetgreen
# 1767      $11-30                                Amber West Village
# 1773      $11-30                                        sweetgreen
# 1810      $11-30                                        sweetgreen
# 1976      $11-30                    Shaking Crab - Upper West Side
# 1984      $11-30                           Jin Ramen - West Harlem
# 1995      $11-30                                        sweetgreen
# 2027      $11-30  Carmine?Ûªs Italian Restaurant - Upper West Side
# 2086   Under $10                 Lahori Chilli Restaurant & Sweets
# 2173      $11-30                                     West End Hall
# 2262      $11-30                                 Bricktown Brewery
# 2302      $11-30                                  Westville - West
# 2310      $31-60                            Boucherie West Village
# 2321      $11-30                      Maxwellâ??s Bar & Restaurant
# 2357      $11-30                               Westville - Wall St
# 2361   Under $10                                 West Bank Gourmet
# 2404      $11-30                            by CHLOE. West Village
# 2450      $11-30                                 Home Sweet Harlem
# 2493      $31-60                            Boucherie West Village
#
#                             restaurant_neighborhood restaurant_rating  \
# 102                                 Lower East Side               4.0
# 165                                    East Village               3.5
# 477                                     Two Bridges               3.0
# 627                                          Harlem               4.0
# 672                                   South Village               4.0
# 760                                     South Tulsa               3.5
# 764                                     South Tulsa               3.0
# 785                                         Midtown               4.0
# 868   Union Square, Greenwich Village, East Village               4.5
# 882                     East Village, Alphabet City               4.0
# 1051                                     Ozone Park               4.5
# 1089                                        TriBeCa               4.0
# 1111                                   West Village               4.0
# 1171                                   West Village               4.5
# 1371                                Upper West Side               4.0
# 1388                                   West Village               4.5
# 1647                              Downtown Brooklyn               4.0
# 1712                                       Flatiron               4.0
# 1743                                   West Village               4.5
# 1757                                   West Village               3.5
# 1767                                   West Village               3.5
# 1773                            Morningside Heights               3.0
# 1810                             Financial District               3.5
# 1976                            Morningside Heights               3.5
# 1984                                         Harlem               4.0
# 1995                            Morningside Heights               3.0
# 2027                                Upper West Side               4.0
# 2086                                       Flatbush               3.5
# 2173                               Manhattan Valley               3.5
# 2262                                        Midtown               4.0
# 2302                                   West Village               4.0
# 2310                                   West Village               4.5
# 2321                          Civic Center, TriBeCa               3.5
# 2357                             Financial District               4.0
# 2361                             Financial District               4.0
# 2404                              Greenwich Village               4.0
# 2450                                         Harlem               4.0
# 2493                                   West Village               4.5
#
#      restaurant_reviewcount restaurant_zipcode      retaurant_address
# 102                    79.0              10002             207 Bowery
# 165                   405.0              10003            104 2nd Ave
# 477                    21.0              10038        45 Catherine St
# 627                   977.0            10027.0          3183 Broadway
# 672                     2.0            10013.0          160 Varick St
# 760                    49.0            74105.0      3535 S Peoria Ave
# 764                    57.0            74135.0        5954 S Yale Ave
# 785                   109.0            74055.0     11909 East 96th St
# 868                   137.0            10003.0            132 4th Ave
# 882                   989.0            10009.0              173 Ave A
# 1051                   18.0              11419        11916 101st Ave
# 1089                   70.0              10013          323 Church St
# 1111                   17.0              10014      39 Christopher St
# 1171                  801.0            10014.0           99 7th Ave S
# 1371                 1156.0            10024.0          2450 Broadway
# 1388                  802.0            10014.0           99 7th Ave S
# 1647                   60.0            11201.0                    NaN
# 1712                  574.0            10001.0          1164 Broadway
# 1743                 1457.0            10014.0         222 Waverly Pl
# 1757                   75.0            10014.0       32 Gansevoort St
# 1767                  192.0            10014.0     135 Christopher St
# 1773                  152.0            10025.0          2937 Broadway
# 1810                  126.0            10005.0             67 Wall St
# 1976                  221.0            10025.0          2869 Broadway
# 1984                  977.0            10027.0          3183 Broadway
# 1995                  152.0            10025.0          2937 Broadway
# 2027                 1155.0            10024.0          2450 Broadway
# 2086                   53.0              11230  1026 Coney Island Ave
# 2173                  208.0              10025          2756 Broadway
# 2262                  107.0            74055.0     11909 East 96th St
# 2302                  906.0            10014.0          210 W 10th St
# 2310                  803.0            10014.0           99 7th Ave S
# 2321                  111.0            10007.0            59 Reade St
# 2357                  115.0            10005.0            110 Wall St
# 2361                   32.0            10006.0             21 West St
# 2404                 1538.0            10012.0        185 Bleecker St
# 2450                  377.0            10031.0     1528 Amsterdam Ave
# 2493                  803.0              10014           99 7th Ave S
#
# [38 rows x 39 columns]

# %%
def get_out_put_1(d,f):
    print(f'''\033[1;31m ###Recommendation{i+1}###  \033[0m''')
    print(f'''restaurant name:                {d.iloc[i,32]}''')
    print(f'''restaurant address:             {d.iloc[i,37]} New York, NY {d.iloc[0,36]}''')
    print(f'''price range:                        {d.iloc[i,31]}''') 
    print(f'''restaurant rating:                {d.iloc[i,34]}''')
    print(f'''restaurant hygiene rate:       {d.iloc[i,20]}''')
    print(f'''restaurant attire:                 {d.iloc[i,5]} ''' )
    print(f'''restaurant parking:              {d.iloc[i,25]}''')
    print(f'''restaurant reservable:          {d.iloc[i,26]}''')
    print(f'''restaurant ambience:           {d.iloc[i,4]}''')

# %%
def get_out_put_2(d,c,g):
    print(f'''\033[1;31m ###Recommendation{i+1}###  \033[0m''')
    print(f'''restaurant name:                {d.iloc[a[i],32]}''')
    print(f'''restaurant address:             {d.iloc[a[i],37]} New York, NY {d.iloc[a[i],36]} ''')
    print(f'''price range:                        {d.iloc[a[i],31]}''')
    print(f'''restaurant rating:                {d.iloc[a[i],34]}''')
    print(f'''restaurant hygiene rate:       {d.iloc[a[i],20]}''')
    print(f'''restaurant attire:                 {d.iloc[a[i],5]}''' )
    print(f'''restaurant ambience:           {d.iloc[a[i],4]}''')
    print(f'''restaurant parking:              {d.iloc[a[i],25]}''')
    print(f'''restaurant reservable:          {d.iloc[a[i],26]}''')

# %%
if a4.shape[0]<=5:
    for i in range(a4.shape[0]):
        get_out_put_1(a4,i)
        print('\n')
elif a4.shape[0]>5:
    a=[]
    list_1=[]
    for q in range(a4.shape[0]):
        list_1.append(a4.iloc[q,34])
    list_1s=sorted(list_1, reverse=True)
    for i in range(len(list_1)):
        if list_1s[0]==list_1[i]:
            a.append(i)
            break
    list_1[a[0]]=-1
    for i in range(len(list_1)):
        if list_1s[1]==list_1[i]:
            a.append(i)
            break
    list_1[a[1]]=-1
    for i in range(len(list_1)):
        if list_1s[2]==list_1[i]:
            a.append(i)
            break
    list_1[a[2]]=-1
    for i in range(len(list_1)):
        if list_1s[3]==list_1[i]:
            a.append(i)
            break
    list_1[a[3]]=-1
    for i in range(len(list_1)):
        if list_1s[4]==list_1[i]:
            a.append(i)
            break
    list_1[a[4]]=-1
    for i in range(len(a)):
        get_out_put_2(a4,i,a)
        print('\n')
elif a4.shape[0]<=0:
    print("Please search again, this time we do not have a restaurant satisfy your need. ")
# Out:
#  ###Recommendation1###
# restaurant name:                $11-30
# restaurant address:             10014 New York, NY 17.0
# price range:                        Free
# restaurant rating:                West Village
# restaurant hygiene rate:       A
# restaurant attire:                 nan
# restaurant ambience:           nan
# restaurant parking:              nan
# restaurant reservable:          Spanish
#
#
#  ###Recommendation2###
# restaurant name:                $31-60
# restaurant address:             10014.0 New York, NY 801.0
# price range:                        Free
# restaurant rating:                West Village
# restaurant hygiene rate:       A
# restaurant attire:                 Casual
# restaurant ambience:           Casual, Trendy, Romantic, Classy
# restaurant parking:              Street
# restaurant reservable:          French
#
#
#  ###Recommendation3###
# restaurant name:                $31-60
# restaurant address:             10014.0 New York, NY 802.0
# price range:                        Free
# restaurant rating:                West Village
# restaurant hygiene rate:       A
# restaurant attire:                 Casual
# restaurant ambience:           Casual, Trendy, Romantic, Classy
# restaurant parking:              Street
# restaurant reservable:          French
#
#
#  ###Recommendation4###
# restaurant name:                Under $10
# restaurant address:             10014.0 New York, NY 1457.0
# price range:                        Free
# restaurant rating:                West Village
# restaurant hygiene rate:       A
# restaurant attire:                 nan
# restaurant ambience:           Casual
# restaurant parking:              Street
# restaurant reservable:          Thai
#
#
#  ###Recommendation5###
# restaurant name:                $11-30
# restaurant address:             10014.0 New York, NY 75.0
# price range:                        No
# restaurant rating:                West Village
# restaurant hygiene rate:       A
# restaurant attire:                 Casual
# restaurant ambience:           Casual, Trendy
# restaurant parking:              nan
# restaurant reservable:          Thai
